# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # subplot

# %%
plt.subplot(2,2,1)
plt.pie([1])
plt.subplot(2,2,2)
plt.pie([1,2])
plt.subplot(2,2,3)
plt.pie([1,2,3])
plt.subplot(2,2,4)
plt.pie([1,2,3,4])
plt.show()

# %%
plt.figure(figsize=(16,9))

plt.subplot(3,2,1)
plt.pie([1,2])

plt.subplot(3,2,2)
plt.pie([1,2,3])

plt.subplot(3,2,3)
plt.pie([1,3,2,4])

plt.subplot(3,2,4)
plt.pie([1,2,3,4,5])

plt.subplot(3,2,5)
plt.pie([1,2,3,4,5,6])

plt.subplot(3,2,6)
plt.pie([1,2,3,4,5,6,7])

plt.show()

# %%
plt.figure(figsize=(16,9))

plt.subplot(3,2,1)

classes=['python','ML','DL','NLP','Computer vision']
class1=[45,55,25,20,65]
classes=['python','ML','DL','NLP','Computer vision']
explode=[0.01,0.02,0.02,0.02,0.1]

colors=['r','g','b','y','c']

textpros={"fontsize":12}

wedgeprops={'linewidth':10,'width':2,'edgecolor':"k"}

plt.pie(class1,labels=classes,explode=explode,colors=colors,autopct='%0.1f%%',shadow=True,radius=2.0,
       startangle=90,pctdistance=0.6,labeldistance=0.3,counterclock=True,center=(2,3))

plt.show()

plt.figure(figsize=(16,9))

plt.subplot(3,2,2)
classes=['python','ML','DL','NLP','CV']
class1=[30,10,20,25,10]
class2=[40,10,30,35,10]
class3=[50,60,70,85,75]

class_index=np.arange(len(classes))
width=5
plt.bar(class_index,class1,align='center',linewidth=2,edgecolor='r',alpha=0.2,linestyle='--',label='Students Marks',color='r') 
plt.bar(class_index+width,class2,align='center',linewidth=2,edgecolor='y',alpha=0.9,linestyle='--',label='Students Marks',color='r')
plt.bar(class_index+width+width,class3,align='center',linewidth=2,edgecolor='k',alpha=0.9,linestyle='--',label='Students Marks',color='g')
plt.xlabel("Subject",fontsize=10)

plt.ylabel('marks',fontsize=10)
plt.grid(True,color='r',linestyle='--',linewidth=1)
plt.title('Marks distribution',fontsize=10)
plt.show()  

plt.figure(figsize=(16,9))

plt.subplot(3,2,3)

ml_student=np.random.randint(18,50,(100))
pl_student=np.random.randint(15,40,(100))
bins=[15,20,25,30,40,45,50] 
plt.hist([ml_student,pl_student],bins,label=['Ml Students','pl students'],color=['b','y'],rwidth=0.8, histtype='bar',align='mid',
         orientation='vertical')
plt.axis([10,50,0,50])

plt.xlabel("Ml_student",fontsize=12)

plt.ylabel("No of students",fontsize=12)

plt.title("Students age Data Set",fontsize=15)

plt.grid(True,c='r',linestyle='--')

plt.legend(loc=0)
                                                                                 
plt.show()

plt.figure(figsize=(16,9))
plt.subplot(3,2,4)

classes=['python','ML','DL','NLP','CV']
class1=[30,10,20,25,10]
class2=[40,10,30,35,10]
class3=[50,60,70,85,75]

class_index=np.arange(len(classes))
width=5

plt.bar(class_index,class1,align='center',linewidth=2,edgecolor='r',alpha=0.2,linestyle='--',label='Students Marks',color='r') 
plt.bar(class_index+width,class2,align='center',linewidth=2,edgecolor='y',alpha=0.9,linestyle='--',label='Students Marks',color='r')
plt.bar(class_index+width+width,class3,align='center',linewidth=2,edgecolor='k',alpha=0.9,linestyle='--',label='Students Marks',color='g')
plt.xlabel("Subject",fontsize=15)

plt.ylabel('marks',fontsize=15)
plt.grid(True,color='r',linestyle='--',linewidth=1)
plt.title('Marks distribution',fontsize=15)
plt.show()  

plt.figure(figsize=(16,9))
plt.subplot(3,2,5)

colors=['r','w','r','w','r','w','r','w','r','w','r','w','r','w','r','w','r','w','r','w','r','w','r','w']
labels=np.ones(24)
plt.pie([1],colors='k',radius=2.05)
plt.pie(labels,colors=colors,radius=2.0)

plt.pie([1],colors='g',radius=1.8)
plt.pie([1],colors='y',radius=1.6)
plt.pie([1],colors='c',radius=1.3)
plt.pie([1],colors='b',radius=1.1)
plt.pie([1],colors='m',radius=0.9)
plt.pie([1],colors='g',radius=1.8)
plt.pie([1],colors='y',radius=1.6)
plt.pie([1],colors='c',radius=1.3)
plt.pie([1],colors='b',radius=1.1)
plt.pie([1],colors='m',radius=0.9)



plt.pie(labels,colors=colors,radius=0.3)

plt.pie([1],colors='w',radius=0.2)
plt.pie([1],colors='k',radius=0.1)

plt.show()
